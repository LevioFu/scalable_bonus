# %%
# %run generateAudio.py --length 6 --symbols symbols.txt --count 1280 --output-dir Training
# Out:
# Generating captchas with symbol set {0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ}
# Creating output directory Training

# %%
# %run generateAudio.py --length 6 --symbols symbols.txt --count 128 --output-dir Validation
# Out:
# Generating captchas with symbol set {0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ}
# Creating output directory Validation

# %%
# %run audioImageConverter.py --input-dir Training --output-dir Training-Spec
# Out:
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
# %run audioImageConverter.py --input-dir Validation --output-dir Validation-Spec
# Out:
# Creating output directory Validation-Spec
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/levio/miniforge3/envs/dataScience/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
# %run train.py --length 6 --symbols symbols.txt --batch-size 32 --epochs 12 --output-model v1 --train-dataset Training-Spec --validate-dataset Validation-Spec
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 80, 80, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 80, 80, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 80, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 80, 80, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 80, 80, 32)   9248        activation[0][0]
# ...
